# %% [markdown]
# **This is Inference Part 1/3, where we run inference for Ernie-Vil-Small. Let me know if you have any questions! 🥶**

# %% [markdown]
# # Data

# %%
# Clone the repo; Get in the data
# !cd ../; git clone -b master https://github.com/Muennighoff/vilio.git
    
# Copy in the data you want to run; All extracted feats here,files that ends with .tsv
# To do so on kaggle, click Add data on the right hand side of your kaggle notebook interface and upload them as datasets
# !cp ../input/features/* ../vilio/ernie-vil/data/hm

# Copy in the hateful memes data from uploading / downloading it
# If you do not have enough disk space split up the training of models!
# If you downloaded the updated HM data; you just need to copy in everything in the data folder (img, .jsonl's)
# Replace the hatefulmemes-data below with the name of your uploaded data
# !cp -r ../input/hatefulmemes-data/* ../vilio/ernie-vil/data/hm/

# %% [markdown]
# ## ES

# %%
# !cd ../vilio/ernie-vil; pip install -r requirements.txt

# %%
# !cd ../vilio/ernie-vil; bash ./bash/inference/ES/hm_ES36.sh /kaggle/input/vilioe36/vilioes/step_2500train \
                                                    /kaggle/input/vilioe36/vilioes/step_2500traindev

# %%
# !cd ../vilio/ernie-vil; bash ./bash/inference/ES/hm_ESVCR36.sh /kaggle/input/vilioesvcr36/vilioes/step_2500train \
                                                    /kaggle/input/vilioesvcr36/vilioes/step_2500traindev

# %%
# !cd ../vilio/ernie-vil; bash ./bash/inference/ES/hm_ESV50.sh /kaggle/input/vilioesv50/vilioes/step_2500train \
                                                    /kaggle/input/vilioesv50/vilioes/step_2500traindev

# %%
# !cd ../vilio/ernie-vil; bash ./bash/inference/ES/hm_ES72.sh /kaggle/input/vilioes72/vilioes/step_2500train \
                                                    /kaggle/input/vilioes72/vilioes/step_2500traindev

# %%
# !cd ../vilio/ernie-vil; bash ./bash/inference/ES/hm_ESVCR72.sh /kaggle/input/vilioesvcr72/vilioes/step_2500train \
                                                    /kaggle/input/vilioesvcr72/vilioes/step_2500traindev

# %%
# Simple Average 5 Seeds
# ens.py
# !cd ../vilio/ernie-vil; bash bash/inference/ES/hm_ESSA.sh

# %%
# Save the output csvs
# !cp -r ../vilio/ernie-vil/data/hm/ES365072/* ./
